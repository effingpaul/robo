# %%
#import sys, os
#sys.path.append(os.path.expanduser('~/git/botop/build'))
#import libry as ry
from robotic import ry
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
C = ry.Config()
#C.addFile(ry.raiPath('../rai-robotModels/scenarios/pandasTable.g'))
C.addFile(ry.raiPath('../rai-robotModels/scenarios/pandaSingle.g'))

obj = C.addFrame('obj')
obj.setPose('t(0. 0.1 0.8)')
obj.setShape(ry.ST.ssBox, size=[.05,.05,.05,.005])
obj.setColor([1,.0,0])
obj.setMass(.1)
obj.setContact(True)
#cameraFrame = C.addFrame("myCamera")
#cameraFrame.setShape(ry.ST.marker, [0.3])
# cameraFrame.setPosition([0,0,2.0])
#cameraFrame.setPosition([0,1.0,2.0])
#cameraFrame.setQuaternion([1,-0.5,0,1])
C.view()
# Out:
# 0

# %%
bot = ry.BotOp(C, False)
bot.home(C)

# %%
rgb, depth = bot.getImageAndDepth("camera")

fig = plt.figure(figsize=(10,5))
axs = fig.subplots(1, 2)
axs[0].imshow(rgb)
axs[1].matshow(depth)
plt.show()
# Out:
# [rai] bot.cpp:getImageAndDepth:294(0) creating camera sensor 'camera'

# %% [markdown]
# From the lecture slides, we learned
# $$\hat x = f\frac{X}{Z}+p_x,~\hat y = f\frac{Y}{Z}+p_y,$$
# where
# - $\hat x, \hat y$ are image coordinates ($u$-$v$ or pixel),
# - $X, Y, Z$ represent camera coordinates, and
# - $p_x, p_y$ are the image offset.
#
# Since we know the $Z$ value of each pixel, we can compute their 3D coordinate (in camera frame):
# $$ X = Z\frac{\hat x-p_x}{f},~  Y = Z\frac{\hat y-p_y}{f}.$$

# %%
fxypxy = bot.getCameraFxypxy("camera")
print(fxypxy)
depth.shape
cameraFrame = C.getFrame("camera")
# Out:
# [322.19998169 322.19998169 320.         180.        ]

# %%
import cv2 as cv
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10,5))
axs = fig.subplots(1, 2)

color = cv.cvtColor(rgb, cv.COLOR_BGR2RGB)

        #cv.imshow('OPENCV - rgb', color)
        
# find redish pixel
color_HSV = cv.cvtColor(color, cv.COLOR_BGR2HSV)

result = color_HSV.copy()
lower1 = np.array([0,15,10])
upper1 = np.array([30,255,255])
mask1 = cv.inRange(color_HSV, lower1, upper1)

lower2 = np.array([330,15,10])
upper2 = np.array([360,255,255])
mask2 = cv.inRange(color_HSV, lower2, upper2)

# display binary mask
result[np.where(mask1==0) and np.where(mask2==0)] = 0
result[np.where(mask1!=0) or  np.where(mask2!=0)] = 255
#cv.imshow('OPENCV - binary mask', result)
axs[0].imshow(result)
# segementation
imgray = cv.cvtColor(result, cv.COLOR_BGR2GRAY)
contours, _ = cv.findContours(imgray, cv.RETR_TREE, cv.CHAIN_APPROX_SIMPLE)

# display segements
#cv.imshow('OPENCV - rgb contours', cv.drawContours(color, contours, -1, (0,255,0), 1))
axs[1].matshow(cv.drawContours(rgb, contours, -1, (0,255,0), 1))
# print center of segment
x = 0
y = 0
w = 0
h = 0
for c in contours:
    #if cv.contourArea(c) <= 50 :
    #    continue    
    x,y,w,h = cv.boundingRect(c)
    x = int(x+ w/2)
    y = int(y+ h/2)
    center = (x,y)
    print (center)

plt.show()
# Out:
# (322, 267)

# %%
fx, fy = fxypxy[0], fxypxy[1]
px, py = fxypxy[2], fxypxy[3]
R, t = cameraFrame.getRotationMatrix(), cameraFrame.getPosition()
H, W = depth.shape



print(px)
print(py)

    
Z = depth[x,y]
#temp = x
#y = x # 0.007, -0.32 , -1.157
#x = temp

point = [1, 2, 3]
## depth is sign-fliped, j: right, i: down
point[0] = Z * (x - px) / fx;
point[1] = -Z * (y - py) / fy;
point[2] = -Z

point[2] -= (w/ fx)*1.5

print(str(point))

## Coordinate transformation (from camera to world) 
#point = R@point 

tmp = C.addFrame( "center of red", 'camera')
tmp.setShape(ry.ST.ssBox, size=[(w/ fx),(h/ fy),(w/ fx),.005])
tmp.setColor([1,0,0,.5])
tmp.setRelativePosition(point)
#tmp.setRelativePose('d(45 0 1 0)')
quat = cameraFrame.getQuaternion()
quat[0] = -quat[0]
tmp.setRelativeQuaternion(quat)
C.view()
# Out:
# 320.0
# 180.0
# [0.006576051706886507, -0.286058249249563, -1.1245787822301805]
# 0

# %%
#C2 = ry.Config()
#pclFrame = C2.addFrame('pcl')
#pclFrame.setPosition(cameraFrame.getPosition())
#pclFrame.setQuaternion(cameraFrame.getQuaternion())
#C.delFrame('pcl')
#pclFrame = C.addFrame('pcl', 'camera')
#
#rgb, points = bot.getPointCloud('camera', False)
#pclFrame.setPointCloud(points, rgb)
#pclFrame.setColor([1.,0.,0.]) #only to see it when overlaying with truth
#C.view_recopyMeshes()
#C.view()

# %%
# manually define frames as an endeff waypoints, relative to box:
way0 = C.addFrame('way0', 'center of red')
way1 = C.addFrame('way1', 'center of red')

way0.setShape(ry.ST.marker, size=[.1])
way0.setRelativePose('t(0 0 .1) d(90 0 0 1)')

way1.setShape(ry.ST.marker, size=[.1])
way1.setRelativePose('d(90 0 0 1)')

C.view()

komo = ry.KOMO()
komo.setConfig(C, True)
komo.setTiming(2., 1, 5., 0)
komo.addControlObjective([], 0, 1e-0)
komo.addObjective([], ry.FS.accumulatedCollisions, [], ry.OT.eq);
komo.addObjective([], ry.FS.jointLimits, [], ry.OT.ineq);
komo.addObjective([1.], ry.FS.poseDiff, ['l_gripper', 'way0'], ry.OT.eq, [1e1]);
komo.addObjective([2.], ry.FS.poseDiff, ['l_gripper', 'way1'], ry.OT.eq, [1e1]);

ret = ry.NLP_Solver() \
    .setProblem(komo.nlp()) \
    .setOptions( stopTolerance=1e-2, verbose=4 ) \
    .solve()
print(ret)

komo.view(False, "waypoints solution")

komo.view_close()
path = komo.getPath()

bot = ry.BotOp(C, False)
bot.home(C)

bot.home(C)

bot.gripperOpen(ry._left)
while not bot.gripperDone(ry._left):
    bot.sync(C, .1)
    

bot.move(path, [2., 3.])
while bot.getTimeToEnd()>0:
    bot.sync(C, .1)
    
bot.gripperClose(ry._left)
while not bot.gripperDone(ry._left):
    bot.sync(C, .1)
    
bot.home(C)

bot.gripperOpen(ry._left)
while not bot.gripperDone(ry._left):
    bot.sync(C, .1)
# Out:
# { time: 0.032014, evals: 36, done: 1, feasible: 1, sos: 5.85022, f: 0, ineq: 0, eq: 0.0499496 }
# ====nlp==== method:AugmentedLagrangian bounded: yes
# ==nlp== it:0 evals:0 mu:1 nu:1 muLB:0.1
# ----newton---- initial point f(x):73.9528 alpha:1 beta:1
# --newton-- it:   1  |Delta|:        0.2  alpha:          1  evals:   2  f(y):    54.5406  ACCEPT
# --newton-- it:   2  |Delta|:        0.2  alpha:          1  evals:   3  f(y):    37.0523  ACCEPT
# --newton-- it:   3  |Delta|:        0.2  alpha:          1  evals:   4  f(y):    22.0792  ACCEPT
# --newton-- it:   4  |Delta|:        0.2  alpha:          1  evals:   5  f(y):     10.374  ACCEPT
# --newton-- it:   5  |Delta|:        0.2  alpha:          1  evals:   6  f(y):    4.73424  ACCEPT
# --newton-- it:   6  |Delta|:        0.2  alpha:          1  evals:   7  f(y):    3.51289  ACCEPT
# --newton-- it:   7  |Delta|:   0.108803  alpha:          1  evals:   8  f(y):    3.37328  ACCEPT
# --newton-- it:   8  |Delta|:  0.0319514  alpha:          1  evals:   9  f(y):    3.35965  ACCEPT
# --newton-- it:   9  |Delta|:  0.0105256  alpha:          1  evals:  10  f(y):    3.35805  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   0  evals:  10  A(x):    3.35805  f:    2.78586  g:          0  h:    2.22351  |x-x'|:   0.866121 	stop:DeltaConverge
# ==nlp== it:   1  evals:  10  A(x):    6.79117  mu:5
# --newton-- it:  10  |Delta|:        0.2  alpha:          1  evals:  11  f(y):    4.33386  ACCEPT
# --newton-- it:  11  |Delta|:   0.078034  alpha:          1  evals:  12  f(y):    4.93393  reject (lineSearch:0)
#                     (line search)        alpha:        0.5  evals:  13  f(y):    4.38636  reject (lineSearch:1)
#                     (line search)        alpha:       0.25  evals:  14  f(y):    4.29537  ACCEPT
# --newton-- it:  12  |Delta|:  0.0351319  alpha:      0.375  evals:  15  f(y):    4.26006  ACCEPT
# --newton-- it:  13  |Delta|:  0.0224107  alpha:     0.5625  evals:  16  f(y):    4.24106  ACCEPT
# --newton-- it:  14  |Delta|:  0.0135798  alpha:    0.84375  evals:  17  f(y):     4.2361  ACCEPT
# --newton-- it:  15  |Delta|: 0.00994394  alpha:          1  evals:  18  f(y):    4.23579  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   1  evals:  18  A(x):    4.23579  f:    3.79231  g:          0  h:   0.439176  |x-x'|:    0.20636 	stop:DeltaConverge
# ==nlp== it:   2  evals:  18  A(x):    5.36575  mu:25
# --newton-- it:  16  |Delta|:  0.0315125  alpha:          1  evals:  19  f(y):    5.33648  ACCEPT
# --newton-- it:  17  |Delta|:  0.0137189  alpha:          1  evals:  20  f(y):    5.33626  ACCEPT
# --newton-- it:  18  |Delta|:  0.0137418  alpha:          1  evals:  21  f(y):    5.33626  ACCEPT
# --newton-- it:  19  |Delta|:  0.0137439  alpha:          1  evals:  22  f(y):    5.33626  ACCEPT
# --newton-- it:  20  |Delta|:  0.0137446  alpha:          1  evals:  23  f(y):    5.33626  ACCEPT
# --newton-- it:  21  |Delta|:  0.0137449  alpha:          1  evals:  24  f(y):    5.33626  ACCEPT
# --newton-- it:  22  |Delta|:  0.0137451  alpha:          1  evals:  25  f(y):    5.33626  ACCEPT
# --newton-- stopping: 'numTinyXSteps>4'
# ==nlp== it:   2  evals:  25  A(x):    5.33626  f:    3.83194  g:          0  h:   0.382161  |x-x'|:  0.0363915 	stop:TinyXSteps (bad:1)
# ==nlp== it:   3  evals:  25  A(x):    10.7938  mu:125
# --newton-- it:  23  |Delta|:  0.0867231  alpha:          1  evals:  26  f(y):    10.7377  ACCEPT
# --newton-- it:  24  |Delta|:   0.117904  alpha:          1  evals:  27  f(y):    10.6015  ACCEPT
# --newton-- it:  25  |Delta|:   0.194445  alpha:          1  evals:  28  f(y):    10.1585  ACCEPT
# --newton-- it:  26  |Delta|:        0.2  alpha:          1  evals:  29  f(y):    9.12243  ACCEPT
# --newton-- it:  27  |Delta|:        0.2  alpha:          1  evals:  30  f(y):    7.63107  ACCEPT
# --newton-- it:  28  |Delta|:        0.2  alpha:          1  evals:  31  f(y):    6.31113  ACCEPT
# --newton-- it:  29  |Delta|:  0.0816967  alpha:          1  evals:  32  f(y):    6.12587  ACCEPT
# --newton-- it:  30  |Delta|:  0.0121819  alpha:          1  evals:  33  f(y):    6.12112  ACCEPT
# --newton-- it:  31  |Delta|: 0.00240402  alpha:          1  evals:  34  f(y):    6.12099  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   3  evals:  34  A(x):    6.12099  f:    5.96057  g:          0  h:  0.0850045  |x-x'|:   0.952979 	stop:DeltaConverge
# ==nlp== it:   4  evals:  34  A(x):     8.2983  mu:625
# --newton-- it:  32  |Delta|:  0.0501727  alpha:          1  evals:  35  f(y):    7.67472  ACCEPT
# --newton-- it:  33  |Delta|: 0.00553964  alpha:          1  evals:  36  f(y):     7.6689  ACCEPT
# --newton-- stopping: 'absMax(Delta)<options.stopTolerance'
# ==nlp== it:   4  evals:  36  A(x):     7.6689  f:    5.85022  g:          0  h:  0.0499496  |x-x'|:  0.0557124 	stop:DeltaConverge
# ==nlp== it:   5  evals:  36  A(x):    15.6995  mu:3125
# --newton-- it:  34  |Delta|:0.000393986 	 -- absMax(Delta)<1e-1*o.stopTolerance -- NO UPDATE
# ==nlp== it:   5  evals:  36  A(x):    15.6995  f:    5.85022  g:          0  h:  0.0499496  |x-x'|:          0 	stop:DeltaConverge
# ==nlp== StoppingCriterion Delta<0.01
# ----newton---- final f(x):15.6995
# [rai] bot.cpp:~BotOp:87(0) shutting down BotOp
# [rai] simulation.cpp:~BotThreadedSim:60(0) shutting down SimThread
# [rai] simulation.cpp:~Simulation:153(0) shutting down Simulation

# %%
C.delFrame('pcl')
# Out:
# [rai] kin.cpp:getFrame:379(-1) cannot find frame named 'pcl'

# %%
bot.sync(C)
# Out:
# False

# %%
cv.destroyAllWindows()
del bot
del C
# Out:
# [rai] bot.cpp:~BotOp:87(0) shutting down BotOp
# [rai] simulation.cpp:~BotThreadedSim:60(0) shutting down SimThread
# [rai] simulation.cpp:~Simulation:153(0) shutting down Simulation
